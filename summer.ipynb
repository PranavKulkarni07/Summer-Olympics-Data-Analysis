# %% [markdown]
# # **Summer** **Olympics** **Data** **Analysis** **Assignment**

# %% [markdown]
# # **Import** **Necessary** **Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mplt
import seaborn as sb

# %%
df=pd.read_csv("summer.csv")

# %%
df.head()
# Out:
#    Year    City     Sport  ... Gender                       Event   Medal
# 0  1896  Athens  Aquatics  ...    Men              100M Freestyle    Gold
# 1  1896  Athens  Aquatics  ...    Men              100M Freestyle  Silver
# 2  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Silver
#
# [5 rows x 9 columns]

# %% [markdown]
# # 1.**In how many cities Summer Olympics is held so far?**

# %%
df['City'].nunique()
# Out:
# 22

# %%
df["City"].unique().tolist()
# Out:
# ['Athens',
#  'Paris',
#  'St Louis',
#  'London',
#  'Stockholm',
#  'Antwerp',
#  'Amsterdam',
#  'Los Angeles',
#  'Berlin',
#  'Helsinki',
#  'Melbourne / Stockholm',
#  'Rome',
#  'Tokyo',
#  'Mexico',
#  'Munich',
#  'Montreal',
#  'Moscow',
#  'Seoul',
#  'Barcelona',
#  'Atlanta',
#  'Sydney',
#  'Beijing']

# %% [markdown]
# ## 2. **Which sport is having most number of Gold Medals so far?**

# %%
df[df['Medal']=="Gold"].Sport.value_counts().head()
# Out:
# Aquatics      1421
# Athletics     1214
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
data=[]
for i,name in enumerate(df[df['Medal']=="Gold"].Sport.value_counts().head().index.tolist()):
   data.append([name,df[df['Medal']=="Gold"].Sport.value_counts().head()[i]])

data
# Out:
# [['Aquatics', 1421],
#  ['Athletics', 1214],
#  ['Rowing', 890],
#  ['Gymnastics', 820],
#  ['Fencing', 552]]

# %%
pd.DataFrame(data,columns=['sport','freq']).sort_values(by='freq',ascending=False).head().plot(x='sport',y='freq',kind='bar',figsize=(5,5))

# %% [markdown]
# # 3.**Which sport is having most number of medals so far?**

# %%
df.Sport.value_counts().head()
# Out:
# Aquatics      4170
# Athletics     3637
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Sport, dtype: int64

# %%
data=[]
for i,name in enumerate(df.Sport.value_counts().index.tolist()):
   data.append([name,df.Sport.value_counts()[i]])

print(data)
# Out:
# [['Aquatics', 4170], ['Athletics', 3637], ['Rowing', 2667], ['Gymnastics', 2307], ['Fencing', 1613], ['Football', 1497], ['Hockey', 1422], ['Wrestling', 1211], ['Shooting', 1150], ['Sailing', 1109], ['Cycling', 1105], ['Basketball', 1012], ['Canoe / Kayak', 1002], ['Volleyball', 994], ['Handball', 973], ['Equestrian', 939], ['Boxing', 894], ['Weightlifting', 591], ['Judo', 491], ['Baseball', 335], ['Archery', 329], ['Tennis', 296], ['Rugby', 192], ['Modern Pentathlon', 180], ['Softball', 180], ['Table Tennis', 144], ['Badminton', 144], ['Taekwondo', 112], ['Tug of War', 94], ['Canoe', 81], ['Polo', 66], ['Lacrosse', 59], ['Golf', 30], ['Skating', 27], ['Ice Hockey', 27], ['Cricket', 24], ['Triathlon', 24], ['Rackets', 10], ['Croquet', 8], ['Water Motorsports', 5], ['Basque Pelota', 4], ['Jeu de paume', 3], ['Roque', 3]]

# %%
pd.DataFrame(data,columns=['sport','freq']).sort_values(by='freq',ascending=False).head().plot(x='sport',y='freq',kind='bar',figsize=(5,5))

# %% [markdown]
# ## **4.Which player has won most number of medals?(Top 5)**

# %%
df.Athlete.value_counts().head()
# Out:
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# ONO, Takashi            13
# MANGIAROTTI, Edoardo    13
# Name: Athlete, dtype: int64

# %%
data=[]
for i,name in enumerate(df.Athlete.value_counts().head().index.tolist()):
   data.append([name,df.Athlete.value_counts().head()[i]])
print(data)
# Out:
# [['PHELPS, Michael', 22], ['LATYNINA, Larisa', 18], ['ANDRIANOV, Nikolay', 15], ['ONO, Takashi', 13], ['MANGIAROTTI, Edoardo', 13]]

# %%
pd.DataFrame(data,columns=['Athlete','freq']).sort_values(by='freq',ascending=False).head().plot(x='Athlete',y='freq',kind='bar',figsize=(5,5))

# %% [markdown]
# # **5.Which player has won most number of Gold Medals?(Top 5)**

# %%
df[df.Medal=="Gold"].Athlete.value_counts().head()
# Out:
# PHELPS, Michael     18
# LEWIS, Carl          9
# NURMI, Paavo         9
# LATYNINA, Larisa     9
# SPITZ, Mark          9
# Name: Athlete, dtype: int64

# %%
data=[]
for i,name in enumerate(df[df.Medal=="Gold"].Athlete.value_counts().head().index.tolist()):
    data.append([name,df[df.Medal=="Gold"].Athlete.value_counts().head()[i]])
print(data)
# Out:
# [['PHELPS, Michael', 18], ['LEWIS, Carl', 9], ['NURMI, Paavo', 9], ['LATYNINA, Larisa', 9], ['SPITZ, Mark', 9]]

# %%
pd.DataFrame(data,columns=['Athlete','freq']).sort_values(by='freq',ascending=False).head().plot(x='Athlete',y='freq',kind='bar',figsize=(5,5))

# %%
data2=[]
for i,name in enumerate(df[df.Medal=="Gold"].Athlete.value_counts().index.tolist()):
    data2.append([name,df[df.Medal=="Gold"].Athlete.value_counts()[i]])
print(data2)
# Out:
# [['PHELPS, Michael', 18], ['LEWIS, Carl', 9], ['NURMI, Paavo', 9], ['LATYNINA, Larisa', 9], ['SPITZ, Mark', 9], ['BIONDI, Matthew', 8], ['EWRY, Ray', 8], ['FISCHER, Birgit', 8], ['THOMPSON, Jenny', 8], ['KATO, Sawao', 8], ['SHAKHLIN, Boris', 7], ['ANDRIANOV, Nikolay', 7], ['CHUKARIN, Viktor Ivanovich', 7], ['CASLAVSKA, Vera', 7], ['GEREVICH, Aladar', 7], ['KLIMKE, Reiner', 6], ['NAKAYAMA, Akinori', 6], ['MANGIAROTTI, Edoardo', 6], ['VAN INNIS, Hubert', 6], ['VAN DYKEN, Amy', 6], ['KOVACS, Pal Adam', 6], ['BOLT, Usain', 6], ['OTTO, Kristin', 6], ['VEZZALI, Valentina', 6], ['KARPATI, Rudolf', 6], ['HOY, Chris', 6], ['SCHERBO, Vitaly', 6], ['FREDRIKSSON, Gert', 6], ['NADI, Nedo', 6], ['ZOU, Kai', 5], ['KIM, Nelli', 5], ['SCHOLLANDER, Donald Arthur', 5], ['ENDO, Yukio', 5], ['ASTAKHOVA, Polina', 5], ['LEE, Willis', 5], ['WINKLER, Hans Günter', 5], ['LIPA, Elisabeta', 5], ['WEISSMULLER, Johnny', 5], ['THORPE, Ian', 5], ['RITOLA, Ville', 5], ['OSBURN, Carl Townsend', 5], ['FISHER, Morris', 5], ['WERTH, Isabell', 5], ['ONO, Takashi', 5], ['HEIDA, Anton', 5], ['ANDRUNACHE, Georgeta', 5], ['DAVYDOVA, Anastasia', 5], ['TSUKAHARA, Mitsuo', 5], ['COMANECI, Nadia', 5], ['PEIRSOL, Aaron', 5], ['LILLOE-OLSEN, Ole Andreas', 5], ['KELETI, Agnes', 5], ['REDGRAVE, Steven', 5], ['LOCHTE, Ryan', 5], ['EGERSZEGI, Krisztina', 5], ['HALL, Gary Jr.', 5], ['LANE, Alfred P.', 5], ['DE BRUIJN, Inge', 4], ['SCHUMANN, Carl', 4], ['ASHFORD, Evelyn', 4], ['LEZAK, Jason', 4], ['ZAMPORI, Giorgio', 4], ['FRASER, Dawn', 4], ['SIDYAK, Viktor', 4], ['PINSENT, Matthew', 4], ['ECKERT-WÖCKEL, Bärbel', 4], ['KRAENZLEIN, Alvin', 4], ['LOUGANIS, Gregory', 4], ['AINSLIE, Ben', 4], ['PULITI, Oreste', 4], ['ZHANG, Yining', 4], ['KROVOPUSKOV, Viktor', 4], ['TORRES, Dara', 4], ['PAVESI, Carlo', 4], ['LIBERG, Einar', 4], ['FELIX, Allyson', 4], ['WANG, Nan', 4], ['IGNAT, Doina', 4], ['NOVIKOVA-BELOVA, Elena', 4], ['GUO, Jingjing', 4], ['MIEZ, Georges', 4], ['RADMILOVIC, Paul', 4], ['SZABO, Ecaterina', 4], ['ELVSTROM, Paul', 4], ['WAGNER-AUGUSTIN, Katrin', 4], ['SUSANU, Viorica', 4], ['FONST, Ramon', 4], ['DELFINO, Giuseppe', 4], ['FU, Mingxia', 4], ['GAUDIN, Lucien', 4], ['KOLEHMAINEN, Hannes', 4], ['WU, Minxia', 4], ['OLSEN, Otto M.', 4], ['KITAJIMA, Kosuke', 4], ['VOLLMER, Dana', 4], ['HURLEY, Marcus', 4], ['TURISCHEVA, Lyudmila', 4], ['KORBUT, Olga', 4], ['DILLARD, Harrison', 4], ['DENG, Yaping', 4], ['KRAYZELBURG, Lenny', 4], ['OWENS, Jesse', 4], ['MATTHES, Roland', 4], ['DARNYI, Tamas', 4], ['TRILLINI, Giovanna', 4], ['SPOONER, Lloyd Spencer', 4], ['OERTER, Alfred', 4], ["D'ORIOLA, Christian", 4], ['SHEPPARD, Melvin', 4], ['PAHUD DE MORTANGES, Charles Ferdinand', 4], ['WILLIAMS, Venus', 4], ['ARTEMOV, Vladimir', 4], ['MCCORMICK, Patricia', 4], ['BLANKERS-KOEN, Fanny', 4], ['NEMOV, Alexei', 4], ['SALNIKOV, Vladimir', 4], ['KULCSAR, Gyözö', 4], ['ZATOPEK, Emil', 4], ['KORZENIOWSKI, Robert', 4], ['LI, Xiaopeng', 4], ['MURATOV, Valentin', 4], ['WIGGINS, Bradley', 4], ['EDWARDS, Teresa', 4], ['POPOV, Alexander', 4], ['FERGUSON, Ian Gordon', 4], ['EVANS, Janet', 4], ['ERMAKOVA, Anastasia', 4], ['JOHNSON, Michael', 4], ['CHEN, Ruolin', 4], ['DANIELS, Charles', 4], ['CARLBERG, G. Vilhelm', 4], ['OLSEN, Jon', 4], ['NABER, John Phillips', 4], ['FRANKLIN, Missy', 4], ['KLOCHKOVA, Yana', 4], ['LESLIE, Lisa', 4], ['PATZAICHIN, Ivan', 4], ['NORELIUS, Martha', 4], ['UPHOFF-BECKER, Nicole', 4], ['BORON, Kathrin', 4], ['KIM, Soo-Nyung', 4], ['POZDNYAKOV, Stanislav', 4], ['SAINT CYR, Henri', 4], ['BEERBAUM, Ludger', 4], ['FUCHS, Jenö', 4], ['WILLIAMS, Serena', 4], ['ENDER, Kornelia', 4], ['ROSE, Murray', 4], ['CUTHBERT, Betty', 4], ['ZIJLAARD-VAN MOORSEL, Leontien', 4], ['VIREN, Lasse', 4], ['MOROZOV, Vladimir', 4], ['MITTS, Heather', 3], ['GYARMATI, Dezso', 3], ['VAN DER VOORT VAN ZIJP, Adolf Dirk C.', 3], ['STEVENSON, Teofilo', 3], ['SAYTIEV, Buvaysa', 3], ['SMITH, Michelle Marie', 3], ['HOCHSCHORNER, Peter', 3], ['CLOETENS, Edmond', 3], ['MEYER, Deborah', 3], ['FIEDLER, Jens', 3], ['SIN ...

# %%
pd.DataFrame(data2,columns=['Athlete','freq']).sort_values(by='freq',ascending=False).head(50).plot(x='Athlete',y='freq',kind="bar",figsize=(20,20))

# %% [markdown]
# # **6.In which year India won first Gold Medal in Summer Olympics?**

# %%
df1=df[df.Medal=="Gold"]
min(df1[df1.Country=="IND"].Year)
# Out:
# 1928

# %% [markdown]
# # **7.Which event is most popular in terms on number of players?(Top 5)**

# %%
df["Event"].value_counts().head()
# Out:
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Event, dtype: int64

# %%
data=[]
for i,name in enumerate(df["Event"].value_counts().head().index.tolist()):
    data.append([name,df["Event"].value_counts().head()[i]])
print(data)
# Out:
# [['Football', 1497], ['Hockey', 1422], ['Team Competition', 1147], ['Basketball', 1012], ['Handball', 973]]

# %%
pd.DataFrame(data,columns=['Event','freq']).sort_values(by='freq',ascending=False).head().plot(x='Event',y='freq',kind='bar',figsize=(5,5))

# %% [markdown]
# # **8.Which sport is having most female Gold Medalists?**

# %%
df3=df[df.Medal=="Gold"]
df3[df3.Gender=="Women"].Sport.value_counts().head()
# Out:
# Aquatics      589
# Athletics     388
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64

# %%
data=[]
for i,name in enumerate(df3[df3.Gender=="Women"].Sport.value_counts().head().index.tolist()):
  data.append([name,df3[df3.Gender=="Women"].Sport.value_counts().head()[i]])
print(data)
# Out:
# [['Aquatics', 589], ['Athletics', 388], ['Gymnastics', 268], ['Rowing', 217], ['Volleyball', 166]]

# %%
pd.DataFrame(data,columns=['Sport','freq']).sort_values(by='freq',ascending=False).head().plot(x='Sport',y='freq',kind='bar',figsize=(5,5))
